# %%
import matplotlib.pyplot as plt
import numpy as np
from NenuRaw_module import Dynspec
from NenuRaw_module import Wav
# Out:
# Bad key backend.qt4 in file /home/lbondonneau/.config/matplotlib/matplotlibrc, line 6 ('backend.qt4        : PyQt4')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
file = '/databf2/nenufar-tf/ES00/2022/02/20220228_154600_20220228_155400_B0809+74_TRACKING/B0809+74_TRACKING_20220228_154637_2.raw'
my_spectra = Dynspec([file],
                     verbose=True,
                     freq_start=70,
                     freq_end=40,
                     start=0.0,  # sec from start
                     duration=4.0,  # sec extracted
                     )
# Out:
# ['/databf2/nenufar-tf/ES00/2022/02/20220228_154600_20220228_155400_B0809+74_TRACKING/B0809+74_TRACKING_20220228_154637_2.raw']
# /databf2/nenufar-tf/ES00/2022/02/20220228_154600_20220228_155400_B0809+74_TRACKING/B0809+74_TRACKING_20220228_154637_2.raw
# 0
# 1
# waveolaf is not a valid format.  Try again...
# int8 67043328
#   blocksize_header  is: 67043328 -> 0.447 sec
#   blocksize_file    is: 67043328
#   overlap    is: 0
#   nbit       is: 8
#   head_size  is: 2316
# /databf2/nenufar-tf/ES00/2022/02/20220228_154600_20220228_155400_B0809+74_TRACKING/B0809+74_TRACKING_20220228_154637_2.raw
# Opening B0809+74_TRACKING_20220228_154637_2.raw
# Block start 0 Block end 9
# Subbloking by factor 2
# Block start 0 Block end 8
# subBlock start 0 subBlock end 1
# Time stat 0.000000. Time end 4.022600

# %%
my_spectra.fourier_computation(fftlen=64,
                               ds_ms=20,
                               pol='I'
                               )
# Out:
# nschan =  349184
# nof_polcpx =  4
# fftlen =  64
# ds =  32
#   ds         is: 31 fftlen 10.158 ms
#   df         is: 1 chan   0.003 MHz
#   nfft       is: 1364
#   fftlen     is: 64 int 0.328 ms
# dedisperse: dm = 0.000000 pc cm-3
# block: 0/8 start: 2022-02-28 15:47:12.000 pol: I
# block 0 from subblock 0 start: 2022-02-28 15:47:12.000 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 1/8 start: 2022-02-28 15:47:12.447 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 2/8 start: 2022-02-28 15:47:12.894 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 3/8 start: 2022-02-28 15:47:13.341 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 4/8 start: 2022-02-28 15:47:13.788 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 5/8 start: 2022-02-28 15:47:14.235 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 6/8 start: 2022-02-28 15:47:14.682 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# block: 7/8 start: 2022-02-28 15:47:15.129 pol: I
# dedisperse: dm = 0.000000 pc cm-3
# ...

# %%
my_spectra.plot_spectra()
# Out:
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# ...

# %%
my_spectra.clean(threshold=30)
my_spectra.rm_baseline()
my_spectra.clean(threshold=10)
my_spectra.plot_dynspec(log10=False)
# Out:
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# findfont: Font family 'Bitstream Vera Sans' not found.
# ...
